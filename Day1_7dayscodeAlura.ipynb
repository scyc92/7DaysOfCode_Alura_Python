# %% [markdown]
# # Dia 1 - Importação de Dados

# %%
# Importar biblioteca

import pandas as pd

# %% [markdown]
# ## Coletando dados do projeto

# %% [markdown]
# ### Dados 1. Empréstimos dos acervos das bibliotecas de UFRN

# %%
df_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
df_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
df_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
df_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
df_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
df_2012_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
df_2013_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
df_2013_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
df_2014_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
df_2014_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
df_2015_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
df_2015_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
df_2016_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
df_2016_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
df_2017_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
df_2017_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
df_2018_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
df_2018_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
df_2019_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
df_2019_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
df_2020_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %% [markdown]
# df_2010_1
# df_2010_2
# df_2011_1
# df_2011_2
# df_2012_1
# df_2012_2
# df_2013_1
# df_2013_2
# df_2014_1
# df_2014_2
# df_2015_1
# df_2015_2
# df_2016_1
# df_2016_2
# df_2017_1
# df_2017_2
# df_2018_1
# df_2018_2
# df_2019_1
# df_2019_2
# df_2020_1

# %%
df_2010_1.head(3)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO

# %%
df_2010_2.head(3)
# Out:
#    id_emprestimo                codigo_barras data_renovacao  \
# 0         799100  S025602_19/11/2013 10:51:34            NaN
# 1         799101                   2008049500            NaN
# 2         799102                      X008043            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/07/01 07:45:41.111000000  2010/07/07 10:52:31.000000000
# 1  2010/07/01 08:08:17.690000000  2010/07/01 09:03:44.000000000
# 2  2010/07/01 08:13:31.574000000  2010/07/09 15:14:44.000000000
#
#    matricula_ou_siape tipo_vinculo_usuario
# 0        2.009050e+09   ALUNO DE GRADUAÇÃO
# 1        2.010056e+09   ALUNO DE GRADUAÇÃO
# 2        2.009043e+09   ALUNO DE GRADUAÇÃO

# %% [markdown]
# #### Unir todos os dataframe de emprestimo em apenas 1 DF

# %%
emprestimo_df = pd.concat([df_2010_1,
df_2010_2,
df_2011_1,
df_2011_2,
df_2012_1,
df_2012_2,
df_2013_1,
df_2013_2,
df_2014_1,
df_2014_2,
df_2015_1,
df_2015_2,
df_2016_1,
df_2016_2,
df_2017_1,
df_2017_2,
df_2018_1,
df_2018_2,
df_2019_1,
df_2019_2,
df_2020_1], ignore_index=True)

# %%
emprestimo_df
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2        2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3        2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...                                ...                            ...
# 2258013  2020/05/05 19:51:06.059000000  2021/05/13 14:53:31.000000000
# 2258014  2020/05/05 19:51:06.135000000  2021/05/13 14:53:38.000000000
# 2258015  2020/05/05 19:51:06.164000000  2021/05/13 15:01:46.000000000
# 2258016  2020/06/09 11:54:02.669000000  2021/07/21 15:33:55.000000000
# 2258017  2020/06/09 11:54:02.852000000  2021/07/21 15:33:45.000000000
#
#          matricula_ou_siape             tipo_vinculo_usuario
# 0              2.008023e+09               ALUNO DE GRADUAÇÃO
# 1              2.008023e+09               ALUNO DE GRADUAÇÃO
# 2              2.008112e+09           ALUNO DE PÓS-GRADUAÇÃO
# 3              2.007211e+08               ALUNO DE GRADUAÇÃO
# 4              2.008023e+09               ALUNO DE GRADUAÇÃO
# ...                     ...                              ...
# 2258013        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258014        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258015        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258016        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
# 2258017        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
#
# [2258018 rows x 7 columns]

# %%
# Quantidade 

emprestimo_df.count()
# Out:
# id_emprestimo           2258018
# codigo_barras           2258018
# data_renovacao           972298
# data_emprestimo         2258018
# data_devolucao          2251547
# matricula_ou_siape      2254848
# tipo_vinculo_usuario    2258018
# dtype: int64

# %%
# Remover Duplicados

emprestimo_df = emprestimo_df.drop_duplicates()

# %%
emprestimo_df.count()
# Out:
# id_emprestimo           2257981
# codigo_barras           2257981
# data_renovacao           972272
# data_emprestimo         2257981
# data_devolucao          2251510
# matricula_ou_siape      2254811
# tipo_vinculo_usuario    2257981
# dtype: int64

# %% [markdown]
# ### Dados 2. Exemplares do acervo

# %%
# !pip install pyarrow
# !pip install fastparquet
# Out:
# Collecting pyarrow
#   Downloading pyarrow-11.0.0-cp38-cp38-macosx_10_14_x86_64.whl (24.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 4.2 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: numpy>=1.16.6 in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from pyarrow) (1.22.3)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-11.0.0
# Collecting fastparquet
#   Downloading fastparquet-2023.2.0-cp38-cp38-macosx_10_9_universal2.whl (794 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 794.6/794.6 kB 22.1 MB/s eta 0:00:00
# Collecting cramjam>=2.3
#   Downloading cramjam-2.6.2-cp38-cp38-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 45.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from fastparquet) (21.3)
# Requirement already satisfied: pandas>=1.5.0 in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from fastparquet) (1.5.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from fastparquet) (1.22.3)
# Collecting fsspec
#   Downloading fsspec-2023.3.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from pandas>=1.5.0->fastparquet) (2022.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from packaging->fastparquet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Users/scyc92/opt/anaconda3/envs/python-3-8/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)
# Installing collected packages: fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.6.2 fastparquet-2023.2.0 fsspec-2023.3.0

# %%
exemplares_df = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')

# %%
exemplares_df.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %% [markdown]
# # Unificar os dois datasets

# %%
df_all = emprestimo_df.merge(exemplares_df)

# %%
df_all.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
# 2  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 3  2010/02/11 11:16:30.335000000  2010/03/04 08:54:32.262000000
# 4  2010/03/04 13:36:26.599000000  2010/03/31 18:04:29.669000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.009122e+09  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# 2        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 3        2.008050e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 4        2.007226e+08      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
#
#                        biblioteca status_material  localizacao  \
# 0  Biblioteca Central Zila Mamede         REGULAR          630
# 1  Biblioteca Central Zila Mamede         REGULAR          630
# 2  Biblioteca Central Zila Mamede         REGULAR          647
# 3  Biblioteca Central Zila Mamede         REGULAR          647
# 4  Biblioteca Central Zila Mamede         REGULAR          647
#
#    registro_sistema
# 0              4225
# 1              4225
# 2             25009
# 3             25009
# 4             25009

# %%
df_all.isnull()
# Out:
#          id_emprestimo  codigo_barras  data_renovacao  data_emprestimo  \
# 0                False          False            True            False
# 1                False          False           False            False
# 2                False          False            True            False
# 3                False          False            True            False
# 4                False          False           False            False
# ...                ...            ...             ...              ...
# 2072517          False          False            True            False
# 2072518          False          False            True            False
# 2072519          False          False            True            False
# 2072520          False          False            True            False
# 2072521          False          False            True            False
#
#          data_devolucao  matricula_ou_siape  tipo_vinculo_usuario  \
# 0                 False               False                 False
# 1                 False               False                 False
# 2                 False               False                 False
# 3                 False               False                 False
# 4                 False               False                 False
# ...                 ...                 ...                   ...
# 2072517           False               False                 False
# 2072518           False               False                 False
# 2072519           False               False                 False
# 2072520            True               False                 False
# 2072521           False               False                 False
#
#          id_exemplar  colecao  biblioteca  status_material  localizacao  \
# 0              False    False       False            False        False
# 1              False    False       False            False        False
# 2              False    False       False            False        False
# 3              False    False       False            False        False
# 4              False    False       False            False        False
# ...              ...      ...         ...              ...          ...
# 2072517        False    False       False            False        False
# 2072518        False    False       False            False        False
# 2072519        False    False       False            False        False
# 2072520        False    False       False            False        False
# 2072521        False    False       False            False        False
#
#          registro_sistema
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 2072517             False
# 2072518             False
# 2072519             False
# 2072520             False
# 2072521             False
#
# [2072522 rows x 13 columns]

# %%
df_all.count()
# Out:
# id_emprestimo           2072522
# codigo_barras           2072522
# data_renovacao           910445
# data_emprestimo         2072522
# data_devolucao          2066344
# matricula_ou_siape      2069629
# tipo_vinculo_usuario    2072522
# id_exemplar             2072522
# colecao                 2072522
# biblioteca              2072522
# status_material         2072522
# localizacao             2072522
# registro_sistema        2072522
# dtype: int64
